# %%
# !pip install matplotlib --upgrade --quiet

# %%
# !pip install seaborn --upgrade --quiet

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yield_apples = [.895,0.91,0.919,0.926,.929,.931]

# %%
plt.plot(yield_apples)

# %%
years = [2010,2011,2012,2013,2014,2015,]
yield_apples =[0.795,0.91,0.919,.90,.899,.894]

# %%
plt.plot(years,yield_apples)

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield(Tons per hectare)');

# %%
years = range(2000,2012)
apples = [0.895,0.91,0.919,.926,.929,0.931,0.934,0.936,0.937,.9375,.9372,0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('year')
plt.ylabel('Yield(Tons per hectare)')
plt.legend(['apples','oranges']);

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
plt.plot(years,oranges,'or')
plt.plot(years,apples,marker='x',c='b',ls='-')
plt.xlabel('year')
plt.ylabel('Yield(Tons of hectare)')
plt.legend(['oranges','apples'])
plt.title('checking graph representation');

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,6))
plt.plot(years,oranges,'or')
plt.plot(years,apples,'s--b')
plt.xlabel('year')
plt.ylabel('Yield(Tons of hectare)')
plt.legend(['oranges','apples'])
plt.title('checking graph representation');

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project='own-python-matplotlib-data-visualization')
# Out:
# [jovian] Creating a new project "abhishekverma01062001/own-python-matplotlib-data-visualization"
# [jovian] Committed successfully! https://jovian.ai/abhishekverma01062001/own-python-matplotlib-data-visualization
# 'https://jovian.ai/abhishekverma01062001/own-python-matplotlib-data-visualization'

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species, s=100);

# %%
import numpy as np
plt.hist(flowers_df.sepal_width,bins=np.arange(2,5,0.25));

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width,alpha=0.4,bins=np.arange(2,5,0.25));
plt.legend(['setosa','versicolor'])

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "abhishekverma01062001/own-python-matplotlib-data-visualization" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/abhishekverma01062001/own-python-matplotlib-data-visualization
# 'https://jovian.ai/abhishekverma01062001/own-python-matplotlib-data-visualization'

# %%
tips_df=sns.load_dataset("tips")

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %% [markdown]
# ##
# Above function barplot is default function in seaborn library.Use simple method or bar function to do it.

# %%
jovian.commit()
